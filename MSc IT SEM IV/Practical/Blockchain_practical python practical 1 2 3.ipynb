# %%
# 1a journal code practical 1a A simple client class that generates the private and public keys by using the built in Python RSA algorithm and test it

# import libraries
import hashlib
import random
import string
import json
import binascii
import numpy as np
import pandas as pd
import pylab as pl
import logging
import datetime
import collections
pip install pycryptodome
# following imports are required by PKI
import Crypto
import Crypto.Random from Crypto.Hash
import SHA from Crypto.PublicKey
import RSA
from Crypto.Signature
import PKCS1_v1_5
import binascii
class Client:
def __init__(self):
random = Crypto.Random.new().read
self._private_key = RSA.generate(1024, random)
self._public_key = self._private_key.publickey()
self._signer = PKCS1_v1_5.new(self._private_key)
@property def
identity(self):
return binascii.hexlify(self._public_key.exportKey(format='DER')).decode('ascii')

class Transaction: def __init__(self,
sender, recipient, value): self.sender =
sender self.recipient = recipient
self.value = value self.time =
datetime.datetime.now()
def to_dict(self):
  if self.sender =="Genesis":
    identity = "Genesis"
  else:
    identity = self.sender.identity
    return collections.OrderedDict({'sender': identity,'recipient': self.recipient,'value': self.value, 'time' : self.time})
def sign_transaction(self):
  private_key = self.sender._private_key signer =PKCS1_v1_5.new(private_key)
  h =SHA.new(str(self.to_dict()).encode('utf8'))
  return binascii.hexlify(signer.sign(h)).decode('ascii')
Dinesh = Client()
Ramesh = Client()
t = Transaction(Dinesh,Ramesh.identity,5.0)
signature = t.sign_transaction()
print(signature)
# Out:
#   File "/tmp/ipython-input-1-3215905472.py", line 13
#     pip install pycryptodome
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install pycryptodome
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 20.0 MB/s eta 0:00:00
# ...

# %%
# import libraries
import hashlib
import random
import string
import json
import binascii
import numpy as np
import pandas as pd
import pylab as pl
import logging
import datetime
import collections

# following imports are required by PKI
import Crypto
import Crypto.Random
from Crypto.Hash import SHA
from Crypto.PublicKey import RSA
from Crypto.Signature import PKCS1_v1_5
import binascii

class Client:
    def __init__(self):
        random_generator = Crypto.Random.new().read
        self._private_key = RSA.generate(1024, random_generator)
        self._public_key = self._private_key.publickey()
        self._signer = PKCS1_v1_5.new(self._private_key)

    @property
    def identity(self):
        return binascii.hexlify(self._public_key.exportKey(format='DER')).decode('ascii')

class Transaction:
    def __init__(self, sender, recipient, value):
        self.sender = sender
        self.recipient = recipient
        self.value = value
        self.time = datetime.datetime.now()

    def to_dict(self):
        if self.sender =="Genesis":
            identity = "Genesis"
        else:
            identity = self.sender
        return collections.OrderedDict({'sender': identity,'recipient': self.recipient,'value': self.value, 'time' : self.time})

    def sign_transaction(self, private_key):
        signer = PKCS1_v1_5.new(private_key)
        h = SHA.new(str(self.to_dict()).encode('utf8'))
        return binascii.hexlify(signer.sign(h)).decode('ascii')

Dinesh = Client()
Ramesh = Client()
t = Transaction(Dinesh.identity,Ramesh.identity,5.0)
signature = t.sign_transaction(Dinesh._private_key)
print(signature)
# Out:
# 

# %%
# 1a chatgpt code practical 1a A simple client class that generates the private and public keys by using the built in Python RSA algorithm and test it

from Crypto.PublicKey import RSA

class Client:
    def __init__(self):
        # Generate RSA key pair (2048 bits)
        key_pair = RSA.generate(2048)
        self.private_key = key_pair.export_key()
        self.public_key = key_pair.publickey().export_key()

    def get_private_key(self):
        return self.private_key.decode('utf-8')

    def get_public_key(self):
        return self.public_key.decode('utf-8')

# 🔧 Test the Client
if __name__ == '__main__':
    alice = Client()
    print("🔐 Alice's Private Key:\n", alice.get_private_key())
    print("\n🪪 Alice's Public Key:\n", alice.get_public_key())
# Out:
# 🔐 Alice's Private Key:
#  -----BEGIN RSA PRIVATE KEY-----
# MIIEowIBAAKCAQEA1Xr7ryJFdVMns1eEV3Jyajwhl5CgvcPlLeL8whqOgdN7Svr8
# zJFI+SxHtDVOF4+kDcSTpfK9mLM96aTbvDnkkWG23saBxLsTKI9JCtpqStkBqBli
# RG3403BGegdO0S+may5WP9qbnuKUoNrK3Dpy/wBKP5ecycPpQJSCE2enmDblitqr
# SFywthMDGBYIRW6yoYG2d1smtX92X9xflc0W7x7zBM4fux/OLaKA+HW6Ov549eIH
# 4lAymTlW3TykKhSbk9JjSCrg776Gep8atgEnwcp0GqsMTfdSXY55DwExx1Qj8jdd
# 2Oct/j2kqSNQEwlFdNH1PNYNz/wPXUYwpvPFPwIDAQABAoIBAC7M/ONKqJ6Ngd0b
# 2RwQr4uhrh2bq9meWh5irlXhW4+TrOpltskkKrLRpdCYhQu+RlFsYJAXdMBGv1J6
# /V848+Z5XQ1eyHE4L/2K2BEEjBvnkijnk7b7wvqbmR/EfV93ykyiBm+OPeKpurq+
# 7I02VSKZTi29z7Yd+INba17UsRW5wL11ed9HoQBPE37amKncKhmHsVz9VI2lH9j5
# OFdrKtcNp4VJLujAvDGZ+Cqgx4F3WEnSXQ8ZrtIal2kqUyoJt9bUgp8jFH+64ch7
# DN67+FIk6Cm7CPMIpWPqHTWtWhwR+mnM51IdMA98mjW55f783ZHf8vQJhcGyFMH2
# 89ljKN0CgYEA6Xt7IDMXSzX/gR7C6XxO2fBJN2PpFgt25UJAnexV29Rhw14kDDQw
# 3sunK8uH6br71w8QCzimlJwbVv8WSK06MnzrlZF8jTW4hVrRCkHeRFttBmEjpq2D
# +iRPBqXlUDvvOpElFLwIApgKbH05wR2yeashtXGmsLV++eAKBjI94TMCgYEA6hGq
# ...

# %%
# 1b chatgpt code practical 1b A transaction class to send and receive money and test it
import hashlib
import json
from Crypto.Signature import pkcs1_15
from Crypto.Hash import SHA256
from Crypto.PublicKey import RSA

class Transaction:
    def __init__(self, sender_public_key, recipient_public_key, amount):
        self.sender = sender_public_key
        self.recipient = recipient_public_key
        self.amount = amount

    def to_dict(self):
        return {
            'sender': self.sender.decode() if isinstance(self.sender, bytes) else self.sender,
            'recipient': self.recipient.decode() if isinstance(self.recipient, bytes) else self.recipient,
            'amount': self.amount
        }

    def sign_transaction(self, sender_private_key):
        private_key = RSA.import_key(sender_private_key)
        tx_hash = SHA256.new(json.dumps(self.to_dict(), sort_keys=True).encode('utf-8'))
        signature = pkcs1_15.new(private_key).sign(tx_hash)
        return signature

    def verify_signature(self, signature):
        try:
            public_key = RSA.import_key(self.sender)
            tx_hash = SHA256.new(json.dumps(self.to_dict(), sort_keys=True).encode('utf-8'))
            pkcs1_15.new(public_key).verify(tx_hash, signature)
            return True
        except (ValueError, TypeError):
            return False

# 🔧 Test Transaction
if __name__ == '__main__':
    sender = Client()
    receiver = Client()

    # Create a transaction
    tx = Transaction(sender.get_public_key(), receiver.get_public_key(), 100)

    # Sign transaction with sender's private key
    signature = tx.sign_transaction(sender.get_private_key())
    print("🖋️ Transaction Signature:", signature.hex())

    # Verify transaction
    is_valid = tx.verify_signature(signature)
    print("✅ Signature Valid?", is_valid)
# Out:
# 🖋️ Transaction Signature: ...
# ✅ Signature Valid? True

# %%
# 2 journal code practical 2 a and b Write the following programs for Blockchain in Python : 7
#a. Create multiple transactions and display them.
#b. Create a blockchain, a genesis block and execute it
import hashlib
import random
import string
import json
import binascii
import numpy as np
import pandas as pd
import pylab as pl
import logging
import datetime
import collections

# following imports are required by PKI
import Crypto
import Crypto.Random
from Crypto.Hash import SHA
from Crypto.PublicKey import RSA
from Crypto.Signature import PKCS1_v1_5
import binascii

# Assuming Client class is defined and available from a previous cell
# If not, you would need to include its definition here as well.

class Transaction:
    def __init__(self, sender, recipient, value):
        self.sender = sender
        self.recipient = recipient
        self.value = value
        self.time = datetime.datetime.now()

    def to_dict(self):
        if self.sender =="Genesis":
            identity = "Genesis"
        else:
            identity = self.sender
        return collections.OrderedDict({'sender': identity,'recipient': self.recipient,'value': self.value, 'time' : self.time})

    def sign_transaction(self, private_key):
        signer = PKCS1_v1_5.new(private_key)
        h = SHA.new(str(self.to_dict()).encode('utf8'))
        return binascii.hexlify(signer.sign(h)).decode('ascii')

def display_transaction(transaction):
  dict = transaction.to_dict()
  print("sender: " + dict['sender'])
  print('-----')
  print ("recipient: " + dict['recipient'])
  print ('-----')
  print ("value: " + str(dict['value']))
  print ('-----')
  print ("time: " + str(dict['time']))
  print ('-----')

transactions = []
Dinesh = Client()
Ramesh = Client()
Seema = Client()
Vijay = Client()
t1 = Transaction( Dinesh.identity, Ramesh.identity, 15.0)
t1.sign_transaction(Dinesh._private_key) # Keep signing call if needed later, but not strictly for display
transactions.append(t1)
t2 = Transaction( Dinesh.identity, Seema.identity, 6.0)
t2.sign_transaction(Dinesh._private_key)
transactions.append(t2)
t3 = Transaction( Ramesh.identity, Vijay.identity, 2.0)
t3.sign_transaction(Ramesh._private_key)
transactions.append(t3)
t4 = Transaction( Seema.identity, Ramesh.identity, 4.0)
t4.sign_transaction(Seema._private_key)
transactions.append(t4)
t5 = Transaction( Vijay.identity, Seema.identity, 7.0)
t5.sign_transaction(Vijay._private_key)
transactions.append(t5)

t6 = Transaction( Ramesh.identity, Seema.identity, 3.0)
t6.sign_transaction(Ramesh._private_key)
transactions.append(t6)
t7 = Transaction( Seema.identity, Dinesh.identity, 8.0)
t7.sign_transaction(Seema._private_key)
transactions.append(t7)
t8 = Transaction( Seema.identity, Ramesh.identity, 1.0)
t8.sign_transaction(Seema._private_key)
transactions.append(t8)
t9 = Transaction( Vijay.identity, Dinesh.identity, 5.0)
t9.sign_transaction(Vijay._private_key)
transactions.append(t9)
t10 = Transaction( Vijay.identity, Ramesh.identity, 3.0)
t10.sign_transaction(Vijay._private_key)
transactions.append(t10)

# Displaying the transactions list (optional based on original intent)
# for transaction in transactions:
#   display_transaction (transaction)
#   print('--------------')

class Block:
    def __init__(self):
        self.verified_transactions = []
        self.previous_block_hash = ""
        self.Nonce= ""

    def hash_block(self):
        # Use SHA256 to hash the block's contents
        sha = hashlib.sha256()
        sha.update(str(self.verified_transactions).encode('utf-8'))
        sha.update(str(self.previous_block_hash).encode('utf-8'))
        sha.update(str(self.Nonce).encode('utf-8'))
        return sha.hexdigest()

last_block_hash = ""
# Dinesh= Client() # Dinesh is already defined above
t0 = Transaction ( "Genesis", Dinesh.identity, 500.0)
block0 = Block()
block0.previous_block_hash = None
Nonce = None # This Nonce variable is not used in the Block class

block0.verified_transactions.append (t0)
digest = block0.hash_block()
last_block_hash= digest
TPCoins = []

def dump_blockchain (blockchain):
  print ("Number of blocks in the chain: " + str(len (blockchain)))
  for x in range (len(blockchain)):
    block_temp =blockchain[x]
    print ("block # " + str(x))
    for transaction in block_temp.verified_transactions:
      display_transaction (transaction)
      print ('--------------')

print ('=====================================')
TPCoins.append (block0)
dump_blockchain(TPCoins)
# Out:
# ...
# Number of blocks in the chain: 1
# block # 0
# sender: Genesis
# -----
# recipient: 
# -----
# value: 500.0
# -----
# time: 2025-06-30 16:41:40.187990
# -----
# --------------

# %%
# 2a chatgpt code  practicl 2a Create multiple transactions and display them.
# transaction.py

class Transaction:
    def __init__(self, sender, receiver, amount):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def __repr__(self):
        return f"Transaction(from: {self.sender}, to: {self.receiver}, amount: {self.amount})"


# Creating multiple transactions
transactions = [
    Transaction("Alice", "Bob", 50),
    Transaction("Bob", "Charlie", 25),
    Transaction("Charlie", "Dave", 10),
    Transaction("Dave", "Alice", 5)
]

# Display the transactions
for tx in transactions:
    print(tx)
# Out:
# Transaction(from: Alice, to: Bob, amount: 50)
# Transaction(from: Bob, to: Charlie, amount: 25)
# Transaction(from: Charlie, to: Dave, amount: 10)
# Transaction(from: Dave, to: Alice, amount: 5)

# %%
# 2b chatgpt code prctical 2b Create a blockchain, a genesis block and execute it.
# blockchain.py
import hashlib
import time

class Block:
    def __init__(self, index, transactions, previous_hash, timestamp=None):
        self.index = index
        self.timestamp = timestamp or time.time()
        self.transactions = transactions
        self.previous_hash = previous_hash
        self.nonce = 0
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        tx_str = ''.join(str(tx) for tx in self.transactions)
        block_string = f"{self.index}{self.timestamp}{tx_str}{self.previous_hash}{self.nonce}"
        return hashlib.sha256(block_string.encode()).hexdigest()

    def __repr__(self):
        return f"Block(index: {self.index}, hash: {self.hash[:10]}..., prev_hash: {self.previous_hash[:10]}...)"

class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        genesis_tx = [Transaction("genesis", "network", 0)]
        return Block(0, genesis_tx, "0")

    def get_last_block(self):
        return self.chain[-1]

    def add_block(self, transactions):
        previous_block = self.get_last_block()
        new_block = Block(len(self.chain), transactions, previous_block.hash)
        self.chain.append(new_block)

    def display_chain(self):
        for block in self.chain:
            print(block)

# If Transaction class is not in same file, import it
class Transaction:
    def __init__(self, sender, receiver, amount):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def __repr__(self):
        return f"({self.sender} -> {self.receiver} : {self.amount})"


# Sample execution
if __name__ == "__main__":
    blockchain = Blockchain()

    tx1 = [Transaction("Alice", "Bob", 100), Transaction("Bob", "Charlie", 50)]
    tx2 = [Transaction("Charlie", "Dave", 25)]

    blockchain.add_block(tx1)
    blockchain.add_block(tx2)

    blockchain.display_chain()
# Out:
# Block(index: 0, hash: 99acf7f20d..., prev_hash: 0...)
# Block(index: 1, hash: 5d8fe2e844..., prev_hash: 99acf7f20d...)
# Block(index: 2, hash: 5a93f12451..., prev_hash: 5d8fe2e844...)

# %%
# 3a chatgpt code practical 3a Create a mining function and test it
import hashlib
import time

DIFFICULTY = 4  # Number of leading zeros required in hash


class Block:
    def __init__(self, index, timestamp, data, previous_hash=''):
        self.index = index
        self.timestamp = timestamp
        self.data = data
        self.previous_hash = previous_hash
        self.nonce = 0
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        block_string = f"{self.index}{self.timestamp}{self.data}{self.previous_hash}{self.nonce}"
        return hashlib.sha256(block_string.encode()).hexdigest()

    def mine_block(self, difficulty=DIFFICULTY):
        print(f"Mining block {self.index}...")
        while self.hash[:difficulty] != '0' * difficulty:
            self.nonce += 1
            self.hash = self.calculate_hash()
        print(f"Block {self.index} mined: {self.hash}")

# %%
# 3b chatgpt code practical 3b Add blocks to the miner and dump the blockchain
class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block(0, time.time(), "Genesis Block", "0")

    def get_latest_block(self):
        return self.chain[-1]

    def add_block(self, new_data):
        last_block = self.get_latest_block()
        new_block = Block(index=last_block.index + 1,
                          timestamp=time.time(),
                          data=new_data,
                          previous_hash=last_block.hash)
        new_block.mine_block()
        self.chain.append(new_block)

    def dump_chain(self):
        for block in self.chain:
            print(f"Block {block.index}")
            print(f"Timestamp: {time.ctime(block.timestamp)}")
            print(f"Data: {block.data}")
            print(f"Hash: {block.hash}")
            print(f"Previous Hash: {block.previous_hash}")
            print(f"Nonce: {block.nonce}")
            print("-" * 40)

# %%
# 3a and 3b combined together
import hashlib
import time

DIFFICULTY = 4  # Number of leading zeros required in hash


class Block:
    def __init__(self, index, timestamp, data, previous_hash=''):
        self.index = index
        self.timestamp = timestamp
        self.data = data
        self.previous_hash = previous_hash
        self.nonce = 0
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        block_string = f"{self.index}{self.timestamp}{self.data}{self.previous_hash}{self.nonce}"
        return hashlib.sha256(block_string.encode()).hexdigest()

    def mine_block(self, difficulty=DIFFICULTY):
        print(f"Mining block {self.index}...")
        while self.hash[:difficulty] != '0' * difficulty:
            self.nonce += 1
            self.hash = self.calculate_hash()
        print(f"Block {self.index} mined: {self.hash}")


class Blockchain:
    def __init__(self):
        self.chain = [self.create_genesis_block()]

    def create_genesis_block(self):
        return Block(0, time.time(), "Genesis Block", "0")

    def get_latest_block(self):
        return self.chain[-1]

    def add_block(self, new_data):
        last_block = self.get_latest_block()
        new_block = Block(index=last_block.index + 1,
                          timestamp=time.time(),
                          data=new_data,
                          previous_hash=last_block.hash)
        new_block.mine_block()
        self.chain.append(new_block)

    def dump_chain(self):
        for block in self.chain:
            print(f"Block {block.index}")
            print(f"Timestamp: {time.ctime(block.timestamp)}")
            print(f"Data: {block.data}")
            print(f"Hash: {block.hash}")
            print(f"Previous Hash: {block.previous_hash}")
            print(f"Nonce: {block.nonce}")
            print("-" * 40)


# === Main Execution ===
if __name__ == "__main__":
    my_blockchain = Blockchain()

    my_blockchain.add_block("First block after Genesis")
    my_blockchain.add_block("Second block data")
    my_blockchain.add_block("Third block data")

    print("\nBlockchain Dump:")
    my_blockchain.dump_chain()
# Out:
# Mining block 1...
# Block 1 mined: 0000a7e75925e161906ff10f539f3177eeba1af0e3ca9baa743baa8db6eab338
# Mining block 2...
# Block 2 mined: 0000b90d4c6db26fc1cf87ceacb1d1a6554084a2baea44620021152584892406
# Mining block 3...
# Block 3 mined: 00001fb0efe44c7cc6c7a7dcc583d4fcdbb64d45cd183d4f7387b579d15361db
#
# Blockchain Dump:
# Block 0
# Timestamp: Mon Jun 30 16:39:11 2025
# Data: Genesis Block
# Hash: 6dc612e224006f3a307b0af7cb95b20eccfdf0c27bdf74ca02512ad613fa9769
# Previous Hash: 0
# Nonce: 0
# ----------------------------------------
# Block 1
# Timestamp: Mon Jun 30 16:39:11 2025
# Data: First block after Genesis
# Hash: 0000a7e75925e161906ff10f539f3177eeba1af0e3ca9baa743baa8db6eab338
# Previous Hash: 6dc612e224006f3a307b0af7cb95b20eccfdf0c27bdf74ca02512ad613fa9769
# Nonce: 123522
# ----------------------------------------
# Block 2
# Timestamp: Mon Jun 30 16:39:12 2025
# Data: Second block data
# Hash: 0000b90d4c6db26fc1cf87ceacb1d1a6554084a2baea44620021152584892406
# ...
